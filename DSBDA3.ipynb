# %% [markdown]
# Name:- Riza James Peter
#
# Roll no:48
#
# Assignment no:3
#
# Descriptive Statistics - Measures of Central Tendency and variability
# Perform the following operations on any open source dataset (e.g., data.csv)
# 1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for
# a dataset (age, income etc.) with numeric variables grouped by one of the qualitative
# (categorical) variable. For example, if your categorical variable is age groups and
# quantitative variable is income, then provide summary statistics of income grouped by
# the age groups. Create a list that contains a numeric value for each response to the
# categorical variable.
# 2. Write a Python program to display some basic statistical details like percentile, mean,
# standard deviation etc. of the Species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Irisversicolor’ of iris.csv dataset.
# Provide the codes with outputs and explain everything that you do in this step.

# %%
#Importig required libraries
import pandas as pd

# %% [markdown]
# Provide summary statistics (mean, median, minimum, maximum, standard deviation) for a dataset (age, income etc.) with numeric variables grouped by one of the qualitative (categorical) variable. For example, if your categorical variable is age groups and quantitative variable is income, then provide summary statistics of income grouped by the age groups. Create a list that contains a numeric value for each response to the categorical variable.

# %%
#Loading students performance dataset
data = pd.read_csv("/content/StudentsPerformance.csv")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# We will group categorical value gender and numeric value math score to provide summary stats (mean, median, minimum, maximum, standard deviation)

# %%
summary_stats =  data.groupby(['gender'])['math score']

# %%
summary_stats.mean()
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
summary_stats.median()
# Out:
# gender
# female    65.0
# male      69.0
# Name: math score, dtype: float64

# %%
summary_stats.min()
# Out:
# gender
# female     0
# male      27
# Name: math score, dtype: int64

# %%
summary_stats.max()
# Out:
# gender
# female    100
# male      100
# Name: math score, dtype: int64

# %%
summary_stats.std()
#deviates from mean score
# Out:
# gender
# female    15.491453
# male      14.356277
# Name: math score, dtype: float64

# %%
summary_stats.describe()
# Out:
#         count       mean        std   min   25%   50%   75%    max
# gender
# female  518.0  63.633205  15.491453   0.0  54.0  65.0  74.0  100.0
# male    482.0  68.728216  14.356277  27.0  59.0  69.0  79.0  100.0

# %% [markdown]
# Write a Python program to display some basic statistical details like percentile, mean, standard deviation etc. of the Species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Irisversicolor’ of iris.csv dataset. Provide the codes with outputs and explain everything that you do in this step.

# %%
df =  pd.read_csv("/content/Iris.csv")

# %%
print("First few rows of the DataFrame:")
df.head()
# Out:
# First few rows of the DataFrame:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print("\nSummary statistics for all columns:")
df.describe()
# Out:
# Summary statistics for all columns:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Statistics of particular columns

# %%
print("\nSummary statistics for SepalLengthCm:")
df["SepalLengthCm"].describe()
# Out:
# Summary statistics for SepalLengthCm:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: SepalLengthCm, dtype: float64

# %%
print("\nSummary statistics for SepalWidthCm:")
df['SepalWidthCm'].describe()
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: SepalWidthCm, dtype: float64

# %%
print("\nSummary statistics for PetalLengthCm:")
df['PetalLengthCm'].describe()
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: PetalLengthCm, dtype: float64

# %%
print("\nSummary statistics for PetalWidthCm:")
df["PetalWidthCm"].describe()
# Out:
# Summary statistics for PetalWidthCm:
# count    150.000000
# mean       1.198667
# std        0.763161
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: PetalWidthCm, dtype: float64

# %%
print("\nSummary statistics grouped by Species:")
df.groupby("Species").describe()
# Out:
# Summary statistics grouped by Species:
#                 SepalLengthCm                                              \
#                         count   mean       std  min    25%  50%  75%  max
# Species
# Iris-setosa              50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor          50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica           50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 SepalWidthCm         ... PetalLengthCm      PetalWidthCm  \
#                        count   mean  ...           75%  max        count
# Species                              ...
# Iris-setosa             50.0  3.418  ...         1.575  1.9         50.0
# Iris-versicolor         50.0  2.770  ...         4.600  5.1         50.0
# Iris-virginica          50.0  2.974  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %% [markdown]
# Statistics of columns based on Species

# %%
# Filter data for 'Iris-setosa', 'Iris-versicolor', and 'Iris-virginica'
setosa_data = df[df['Species'] == 'Iris-setosa']
versicolor_data = df[df['Species'] == 'Iris-versicolor']
virginica_data = df[df['Species'] == 'Iris-virginica']

# %%
setosa_data.describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
versicolor_data.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
virginica_data.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000
